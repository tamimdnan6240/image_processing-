# %%
import torch
import torchvision.transforms as transforms
from torchvision.utils import save_image
import cv2 
from matplotlib import pyplot as plt
import numpy as np
from torchvision import transforms, models

# %%
from image_rotation_display_flipping import Load_Image, display_images, rotate

# %%
## load the image 
img = Load_Image("D:\\SPRING 2023\\MS_Thesis\\MASTER'S THESIS\\Deep Crack Model\\DeepCrack-master\\codes\\data\\CRACKTREE260\\crack_train_image_512x512\\crack_train_image-10000.jpg")
msk = Load_Image("D:\\SPRING 2023\\MS_Thesis\\MASTER'S THESIS\\Deep Crack Model\\DeepCrack-master\\codes\\data\\CRACKTREE260\\crack_train_mask_512x512\\crack_train_mask-10000.png")

# %%
display_images(img, msk)

# %% [markdown]
# ## Rotation

# %%
rot_image_10, rot_mask_10 = rotate(img, msk, 10) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_10, rot_mask_10)

rot_image_10 = cv2.cvtColor(rot_image_10, cv2.COLOR_RGB2BGR)
rot_mask_10 = cv2.cvtColor(rot_mask_10, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_10.jpg", rot_image_10)
cv2.imwrite("rot_mask_10.png",rot_mask_10)
# Out:
# True

# %%
rot_image_20, rot_mask_20 = rotate(img, msk, 20) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_20, rot_mask_20)

rot_image_20 = cv2.cvtColor(rot_image_20, cv2.COLOR_RGB2BGR)
rot_mask_20 = cv2.cvtColor(rot_mask_20, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_20.jpg", rot_image_20)
cv2.imwrite("rot_mask_20.png",rot_mask_20)
# Out:
# True

# %%
rot_image_30, rot_mask_30 = rotate(img, msk, 30) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_30, rot_mask_30)

rot_image_30 = cv2.cvtColor(rot_image_30, cv2.COLOR_RGB2BGR)
rot_mask_30 = cv2.cvtColor(rot_mask_30, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_30.jpg", rot_image_30)
cv2.imwrite("rot_mask_30.png",rot_mask_30)
# Out:
# True

# %%
rot_image_40, rot_mask_40 = rotate(img, msk, 40) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_40, rot_mask_40)

rot_image_40 = cv2.cvtColor(rot_image_40, cv2.COLOR_RGB2BGR)
rot_mask_40 = cv2.cvtColor(rot_mask_40, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_40.jpg", rot_image_40)
cv2.imwrite("rot_mask_40.png",rot_mask_40)
# Out:
# True

# %%
rot_image_50, rot_mask_50 = rotate(img, msk, 50) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_50, rot_mask_50)

rot_image_40 = cv2.cvtColor(rot_image_50, cv2.COLOR_RGB2BGR)
rot_mask_40 = cv2.cvtColor(rot_mask_50, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_50.jpg", rot_image_50)
cv2.imwrite("rot_mask_50.png",rot_mask_50)
# Out:
# True

# %%
rot_image_60, rot_mask_60 = rotate(img, msk, 60) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_60, rot_mask_60)

rot_image_60 = cv2.cvtColor(rot_image_60, cv2.COLOR_RGB2BGR)
rot_mask_60 = cv2.cvtColor(rot_mask_60, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_60.jpg", rot_image_60)
cv2.imwrite("rot_mask_60.png",rot_mask_60)
# Out:
# True

# %%
rot_image_70, rot_mask_70 = rotate(img, msk, 70) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_70, rot_mask_70)

rot_image_70 = cv2.cvtColor(rot_image_70, cv2.COLOR_RGB2BGR)
rot_mask_70 = cv2.cvtColor(rot_mask_70, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_70.jpg", rot_image_70)
cv2.imwrite("rot_mask_70.png",rot_mask_70)
# Out:
# True

# %%
rot_image_80, rot_mask_80 = rotate(img, msk, 80) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_80, rot_mask_80)

rot_image_80 = cv2.cvtColor(rot_image_80, cv2.COLOR_RGB2BGR)
rot_mask_80 = cv2.cvtColor(rot_mask_80, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_80.jpg", rot_image_80)
cv2.imwrite("rot_mask_80.png",rot_mask_80)
# Out:
# True

# %%
rot_image_90, rot_mask_90 = rotate(img, msk, 90) ## positive value input means counter-clockwise and negative means clockwise. 

display_images(rot_image_90, rot_mask_90)

rot_image_90 = cv2.cvtColor(rot_image_90, cv2.COLOR_RGB2BGR)
rot_mask_90 = cv2.cvtColor(rot_mask_90, cv2.COLOR_RGB2BGR)


## Saving the images
cv2.imwrite("rot_image_90.jpg", rot_image_90)
cv2.imwrite("rot_mask_90.png",rot_mask_90)
# Out:
# True
