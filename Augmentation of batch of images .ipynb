# %%
import torch
import torchvision.transforms as transforms
from torchvision.utils import save_image
import cv2 
from matplotlib import pyplot as plt
import numpy as np
from torchvision import transforms, models
import matplotlib.image as mpimg 
from PIL import Image
import numpy as np
from numpy import asarray
import glob
import os
import imageio
import imgaug as ia
from imgaug import augmenters as iaa

# %%
# we define a python file for our convenicences to make some operations
from image_msk_Load_rotate_display__resize_CenterCrop_RadndoFlipping import Load_Image, display_images, rotate, RandomFlip, centerCrop, resize

# %% [markdown]
# ## CenterCrop Operation to all images and corresponding masks
#
# #### 1. We need this because required input size in DeepCrack is 512 x 512. Resizing is making distortions, so CenterCrop is producing better results.
#
# #### 2. Load all images and their masks
#
# #### 3. create a loop to apply Center Crop oeration
#
# ### Complete step:
#
# ##### a. load the images folder and masks folder containing all the images and masks using cv2.glob.glob. So, full image folder is loaded.
# ##### b. Now create a loop to bring one by one image and corresponding mask.
# ##### c. Now apply CenterCrop function: CenterCrop(image, mask, (512, 512)).
# ##### d. Create a direcotry to save all the centercropped images.
# ##### d. now again save each images and masks by their loop id.

# %% [markdown]
# # Load image_folder and mask_folder

# %%
image_folder = glob.glob("C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\*jpg")
mask_folder = glob.glob("C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\*bmp")

# %%
image_folder
# Out:
# ['C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6192.jpg',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6193.jpg',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6194.jpg',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6195.jpg',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6196.jpg',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6197.jpg',
# ...

# %%
mask_folder
# Out:
# ['C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6192.bmp',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6193.bmp',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6194.bmp',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6195.bmp',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6196.bmp',
#  'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6197.bmp',
# ...

# %%
## Use PIL Image to resize, and crop image


for images in 
# resize image and force a new shape
from PIL import Image
# load the image
image = Image.open('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image\\6192.jpg')
# report the size of the image
print(image.size)
# resize image and ignore original aspect ratio
img_resized = image.resize((200,200))
# report the size of the thumbnail
print(img_resized.size)
# show the image
# img_resized.show()
plt.imshow(img_resized, cmap = 'gray')
plt.show
# Out:
# (800, 600)
# (200, 200)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Use PIL Image to resize, and crop image

# resize image and force a new shape
from PIL import Image
# load the image
image = Image.open('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt\\6192.bmp')
# report the size of the image
print(image.size)
# resize image and ignore original aspect ratio
img_resized = image.resize((200,200))
# report the size of the thumbnail
print(img_resized.size)
# show the image
# img_resized.show()
plt.imshow(img_resized, cmap = 'gray')
plt.show
# Out:
# (800, 600)
# (200, 200)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import os
from PIL import Image

# set the input directory containing the images
input_folder = "C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\image"

# set the output directory for the resized images
output_folder = 'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\resized_image'

# set the desired output size
output_size = (512, 512)

# create the output directory if it does not exist
os.makedirs(output_folder, exist_ok=True)

# loop through each image in the input directory
for image_name in os.listdir(input_folder):
    # read the image
    image_path = os.path.join(input_folder, image_name)
    image = Image.open(image_path)
    
    # resize the image to the desired output size
    image_resized = image.resize(output_size)
    
    # save the resized image to the output directory with a new filename
    output_name = f"resized_{image_name}"
    output_path = os.path.join(output_folder, output_name)
    image_resized.save(output_path)

# %%
import os
from PIL import Image

# set the input directory containing the images
input_folder = 'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\gt'

# set the output directory for the resized images
output_folder = 'C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_(tamim)\\DeepCrack_Master\\codes\\data\\CRACKTREE260\\resized_mask'

# set the desired output size
output_size = (512, 512)

# create the output directory if it does not exist
os.makedirs(output_folder, exist_ok=True)

# loop through each image in the input directory
for image_name in os.listdir(input_folder):
    # read the image
    image_path = os.path.join(input_folder, image_name)
    image = Image.open(image_path)
    
    # resize the image to the desired output size
    image_resized = image.resize(output_size)
    
    # save the resized image to the output directory with a new filename
    output_name = f"resized_{image_name}"
    output_path = os.path.join(output_folder, output_name)
    image_resized.save(output_path)

# %% [markdown]
# # Augmentation Pipeline on  a single image

# %%
seq = iaa.Sequential([
    iaa.Affine(rotate=(0, 4)),
    iaa.AdditiveGaussianNoise(scale=(10, 60)),
    iaa.AddToHueAndSaturation((-60, 60)),  # change their color
    iaa.ElasticTransformation(alpha=90, sigma=9),  # water-like effect
    iaa.Crop(percent=(0, 0.2))
    
], random_order=True)

## image list (tuple)
images = [img_1] 

images_aug = seq(images=images)

print("Augmented:")
plt.imshow(np.hstack(images_aug))
plt.show()
plt.savefig('11.png')
# Out:
# Augmented:

# %% [markdown]
# # Augmentation pipeline on

# %%
seq = iaa.Sequential([
    iaa.Affine(rotate=(0, 4)),
    iaa.AdditiveGaussianNoise(scale=(10, 60)),
    iaa.AddToHueAndSaturation((-60, 60)),  # change their color
    iaa.ElasticTransformation(alpha=90, sigma=9),  # water-like effect
    iaa.Crop(percent=(0, 0.2))
    
], random_order=True)

## image list (tuple)
images =  [
    imageio.imread('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_Master\\codes\\data\\EdmCrack600\\Data_Structure_RAW\\Transverse_cracks\\10.png'),
    imageio.imread('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_Master\\codes\\data\\EdmCrack600\\Data_Structure_Annotated\\Transverse_cracks\\10.png')
]

images_aug = seq(images=images)

# visualize the image
print((images[0].shape, images_aug[0].shape))
plt.imshow(np.hstack([images[0], images_aug[0]]))
plt.show()

# visualize the mask
print((images[1].shape, images_aug[1].shape))
plt.imshow(np.hstack([images[1], images_aug[1]]))
plt.show()
# Out:
# C:\Users\tamim\AppData\Local\Temp\ipykernel_28340\3524671014.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imageio.imread('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_Master\\codes\\data\\EdmCrack600\\Data_Structure_RAW\\Transverse_cracks\\10.png'),
# C:\Users\tamim\AppData\Local\Temp\ipykernel_28340\3524671014.py:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# ...

# %% [markdown]
# ## Augmentation pipeline with pytorch (not working yet)

# %%
data_augment_op = transforms.Compose([
    transforms.ColorJitter(brightness=(0.5,1.5),contrast=(1),saturation=(0.5,1.5),hue=(-0.1,0.1)),
    transforms.GaussianBlur(kernel_size=(7, 13), sigma=(0.1, 0.2)),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

## image list (tuple)
images =  Image.open('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_Master\\codes\\data\\EdmCrack600\\Data_Structure_RAW\\Transverse_cracks\\10.png')

images_aug = data_augment_op(images)

# visualize the results
print((images[0].shape, images_aug[0].shape))
plt.imshow(np.hstack([images[0], images_aug[0]]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 13
#      10 ## image list (tuple)
#      11 images =  Image.open('C:\\Users\\tamim\\OneDrive - University of North Carolina at Charlotte\\DeepCrack_Master\\codes\\data\\EdmCrack600\\Data_Structure_RAW\\Transverse_cracks\\10.png')
# ---> 13 images_aug = data_augment_op(images)
#      15 # visualize the results
#      16 print((images[0].shape, images_aug[0].shape))
#
# File ~\anaconda3\envs\DeepCrack\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~\anaconda3\envs\DeepCrack\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
# ...

# %% [markdown]
# ## create loop to bring images and corresponding masks

# %%
image_saved = 'cropped_512x512'

if not os.path.exists(image_saved): 
    os. mkdir(image_saved)

# %% [markdown]
# for img_path in image_folder:
#     image = Load_Image(img_path)
#     image = centerCrop1(image, (512, 512))
#     image = asarray(image)
#     image_save_path = os.path.join(image_saved, os.path.splitext(img_path)[0] + 'cropped_image.png') ## to bring and save the images based on previosus id
#     Image.fromarray(image).save(image_save_path)
#     plt.imshow(np.hstack((image)), cmap = 'gray')
# image_saved = 'cropped_512x512'
#
# if not os.path.exists(image_saved):
#     os. mkdir(image_saved)    plt.show()

# %% [markdown]
# msk_saved = 'msk_cropped_512x512'
#
# if not os.path.exists(msk_saved):
#     os. mkdir(msk_saved)
#
# for msk_path in mask_folder:
#     msk = Load_Image(msk_path)
#     msk = centerCrop1(msk, (512, 512))
#     msk = asarray(msk)
#     msk_save_path = os.path.join(msk_saved, os.path.splitext(msk_path)[0] + 'cropped_msk.png') ## to bring and save the images based on previosus id
#     Image.fromarray(image).save(image_save_path)
#     plt.imshow(np.hstack((msk)), cmap = 'gray')
#     plt.show()
